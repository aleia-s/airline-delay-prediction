# %%
import pandas as pd 
import numpy as np

# %%
flights = pd.read_csv('flights-23-8-24-8.csv',
                      dtype={'Reporting_Airline': 'category', 
                             'Flight_Number_Reporting_Airline': 'uint16',
                             'Origin': 'category',
                             'Dest': 'category',
                             'DepDelay': 'float32',
                             'ArrDelay': 'float32',
                             'Cancelled': 'bool',
                             'CancellationCode': 'category'}, 
                      parse_dates=['DepTimestamp', 'ArrTimestamp'])

# %%
airports = np.unique(flights[['Origin', 'Dest']].values)

# %%
import csv
with open('airports.txt', 'w', newline='\n') as f: 
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(airports)

# %% [markdown]
# The code below is a modified version of the IEM scraper example from IEM's ASOS scripts available on their Github.

# %%
"""
Example script that scrapes data from the IEM ASOS download service
Source: https://github.com/akrherz/iem/blob/master/scripts/asos/iem_scraper_example.py
Utilizes this service: https://mesonet.agron.iastate.edu/request/download.phtml
"""
from __future__ import print_function
import json
import time
import datetime
# Python 2 and 3: alternative 4
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen

# Number of attempts to download data
MAX_ATTEMPTS = 6
# HTTPS here can be problematic for installs that don't have Lets Encrypt CA
SERVICE = "http://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?"


def download_data(uri):
    """Fetch the data from the IEM

    The IEM download service has some protections in place to keep the number
    of inbound requests in check.  This function implements an exponential
    backoff to keep individual downloads from erroring.

    Args:
      uri (string): URL to fetch

    Returns:
      string data
    """
    attempt = 0
    while attempt < MAX_ATTEMPTS:
        try:
            data = urlopen(uri, timeout=300).read().decode('utf-8')
            if data is not None and not data.startswith('ERROR'):
                return data
        except Exception as exp:
            print("download_data(%s) failed with %s" % (uri, exp))
            time.sleep(5)
        attempt += 1

    print("Exhausted attempts to download, returning empty data")
    return ""


def get_stations_from_filelist(filename):
    """Build a listing of stations from a simple file listing the stations.

    The file should simply have one station per line.
    """
    stations = []
    for line in open(filename):
        stations.append(line.strip())
    return stations


def get_stations_from_networks():
    """Build a station list by using a bunch of IEM networks."""
    stations = []
    states = """AK AL AR AZ CA CO CT DE FL GA HI IA ID IL IN KS KY LA MA MD ME
     MI MN MO MS MT NC ND NE NH NJ NM NV NY OH OK OR PA RI SC SD TN TX UT VA VT
     WA WI WV WY"""
    # IEM quirk to have Iowa AWOS sites in its own labeled network
    networks = ['AWOS']
    for state in states.split():
        networks.append("%s_ASOS" % (state,))

    for network in networks:
        # Get metadata
        uri = ("https://mesonet.agron.iastate.edu/"
               "geojson/network/%s.geojson") % (network,)
        data = urlopen(uri)
        jdict = json.load(data)
        for site in jdict['features']:
            stations.append(site['properties']['sid'])
    return stations


def main():
    """Our main method"""
    # timestamps in UTC to request data for
    startts = datetime.datetime(2023, 8, 1)
    endts = datetime.datetime(2024, 8, 31)

    service = SERVICE + "data=sknt&data=p01i&data=vsby&data=gust&data=skyc1&data=skyc2&data=skyc3&data=skyl1&data=skyl2&data=skyl3&data=wxcodes&tz=Etc/UTC&format=onlycomma&latlon=no&"

    service += startts.strftime('year1=%Y&month1=%m&day1=%d&')
    service += endts.strftime('year2=%Y&month2=%m&day2=%d&')

    # Two examples of how to specify a list of stations
    # stations = get_stations_from_networks()
    stations = get_stations_from_filelist("airports.txt")
    for station in stations:
        uri = '%s&station=%s' % (service, station)
        print('Downloading: %s' % (station, ))
        data = download_data(uri)
        outfn = 'weather/%s.csv' % (station)
        out = open(outfn, 'w')
        out.write(data)
        out.close()


if __name__ == '__main__':
    main()
# Out:
# Downloading: ABQ
# Downloading: AMA
# Downloading: ANC
# Downloading: ASE
# Downloading: ATL
# Downloading: AUS
# Downloading: BHM
# Downloading: BNA
# Downloading: BOS
# Downloading: BRO
# Downloading: BTR
# Downloading: BWI
# Downloading: BZN
# Downloading: CHS
# Downloading: CLE
# Downloading: CLT
# Downloading: CMH
# Downloading: COS
# Downloading: CRP
# Downloading: CVG
# Downloading: DAL
# Downloading: DCA
# Downloading: DEN
# Downloading: DFW
# Downloading: DSM
# Downloading: DTW
# Downloading: ECP
# Downloading: EGE
# Downloading: ELP
# Downloading: EWR
# Downloading: EYW
# Downloading: FCA
# Downloading: FLL
# Downloading: GPT
# Downloading: GRR
# Downloading: GSP
# Downloading: HDN
# Downloading: HNL
# Downloading: HOB
# Downloading: HRL
# Downloading: IAD
# Downloading: IAH
# Downloading: ICT
# Downloading: IND
# Downloading: JAC
# Downloading: JAX
# Downloading: JFK
# Downloading: LAS
# Downloading: LAX
# Downloading: LBB
# Downloading: LCH
# Downloading: LFT
# Downloading: LGA
# Downloading: LIT
# Downloading: LRD
# Downloading: MAF
# Downloading: MCI
# Downloading: MCO
# Downloading: MDW
# Downloading: MEI
# Downloading: MEM
# Downloading: MFE
# Downloading: MIA
# Downloading: MKE
# Downloading: MOB
# Downloading: MSN
# Downloading: MSP
# Downloading: MSY
# Downloading: MTJ
# Downloading: OKC
# Downloading: OMA
# Downloading: ONT
# Downloading: ORD
# Downloading: ORF
# Downloading: PBI
# Downloading: PDX
# Downloading: PHL
# Downloading: PHX
# Downloading: PIB
# Downloading: PIT
# Downloading: PNS
# Downloading: PSP
# Downloading: RDU
# Downloading: RIC
# Downloading: RNO
# Downloading: RSW
# Downloading: SAN
# Downloading: SAT
# Downloading: SAV
# Downloading: SDF
# Downloading: SEA
# Downloading: SFO
# Downloading: SGF
# Downloading: SJC
# Downloading: SJU
# Downloading: SLC
# Downloading: SMF
# Downloading: SNA
# Downloading: STL
# Downloading: STT
# Downloading: TPA
# Downloading: TUL
# Downloading: TUS
# Downloading: TVC
# Downloading: TYS
# Downloading: VCT
# Downloading: XNA

# %% [markdown]
# Now, each flight's departure and arrival airport needs to have the correct weather data associated with it, based on the correspondingly scheduled departure and arrival times.

# %%
import pandas as pd
import numpy as np 
import datetime as dt

# Load weather data with valid column as datetime index
airport_wx = {}
for airport in airports:
    ix = pd.read_csv(
        f'weather/{airport}.csv',
        parse_dates=['valid'],
        dtype={
            'station': 'category',
            'skyc1': 'category',
            'skyc2': 'category',
            'skyc3': 'category',
            'wxcodes': 'category'
        }
    )
    # Ensure valid is the datetime index
    ix.set_index('valid', inplace=True)
    airport_wx[airport] = ix


# For a given airport and timestamp, return cleaned and formatted weather data for the closest timestamp
def get_wx(airport, ts):
    if pd.isna(ts) or airport not in airport_wx:
        # Return default values for missing timestamps or invalid airports
        return pd.DataFrame({'ceiling': [25000], 'wind': [0], 'visibility': [10], 'precip': [0]})

    airport_wxdf = airport_wx[airport]
    #print(f"Flight Timestamp: {ts}")
    #print(f"Weather Data Timestamps: {airport_wxdf.index[:5]}")


    # Find the closest timestamp using numpy's abs
    try:
        deltas = np.abs(airport_wxdf.index - ts)
        closest_idx = deltas.argmin()  # Get the index of the smallest difference
        airport_wx_data = airport_wxdf.iloc[closest_idx]
    except Exception as e:
        print(f"Error finding closest timestamp for {airport} at {ts}: {e}")
        # Return default values if matching fails
        return pd.DataFrame({'ceiling': [25000], 'wind': [0], 'visibility': [10], 'precip': [0]})

    # Process weather data
    ceiling = 25000
    if airport_wx_data['skyc1'] in ['OVC', 'BKN']:
        ceiling = pd.to_numeric(airport_wx_data['skyl1'], errors='coerce', downcast='unsigned')
    elif airport_wx_data['skyc2'] in ['OVC', 'BKN']:
        ceiling = pd.to_numeric(airport_wx_data['skyl2'], errors='coerce', downcast='unsigned')
    elif airport_wx_data['skyc3'] in ['OVC', 'BKN']:
        ceiling = pd.to_numeric(airport_wx_data['skyl3'], errors='coerce', downcast='unsigned')

    wind = pd.to_numeric(airport_wx_data.get('sknt', 0), errors='coerce', downcast='unsigned')
    visibility = pd.to_numeric(airport_wx_data.get('vsby', 10), errors='coerce', downcast='unsigned')
    precip = pd.to_numeric(airport_wx_data.get('p01i', 0), errors='coerce', downcast='unsigned')

    return pd.DataFrame({'ceiling': [ceiling], 'wind': [wind], 'visibility': [visibility], 'precip': [precip]})

# For a single flight, return a Series containing the origin and destination weather
def get_wx_for_flights(df):
    origin_airport = df['Origin']
    scheduled_departure = df['DepTimestamp']
    destination_airport = df['Dest']
    scheduled_arrival = df['ArrTimestamp']

    # Handle missing timestamps
    origin_wx = get_wx(origin_airport, scheduled_departure)
    destination_wx = get_wx(destination_airport, scheduled_arrival)
    
    #print("Origin Weather:", origin_wx)
    #print("Destination Weather:", destination_wx)
    
    origin_wx = origin_wx.add_prefix('ORIGIN_').iloc[0]
    destination_wx = destination_wx.add_prefix('DEST_').iloc[0]
    return pd.concat([origin_wx, destination_wx])


# Apply weather data processing to each row
wx_data = flights.apply(lambda x: get_wx_for_flights(x), axis=1)

print(wx_data.head())
print(wx_data.iloc[0])  # Inspect the first row's weather data


# Combine all the DataFrames in wx_data into a single DataFrame
#wx_df = pd.concat([pd.DataFrame([row]) for row in wx_data], ignore_index=True)
#print(wx_df.head())
#print(wx_df.iloc[0])  # Inspect the first row's weather data

# Concatenate the flight and weather DataFrames
flights.reset_index(drop=True, inplace=True)
flights_with_wx = pd.concat([flights, wx_data], axis=1)
flights_with_wx.to_csv('flights-wx.csv', index=False)
print("Data saved to 'flights-wx.csv'")
# Out:
# C:\Users\ams21\AppData\Local\Temp\ipykernel_6624\3340997814.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   ix = pd.read_csv(
# C:\Users\ams21\AppData\Local\Temp\ipykernel_6624\3340997814.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   ix = pd.read_csv(
# C:\Users\ams21\AppData\Local\Temp\ipykernel_6624\3340997814.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   ix = pd.read_csv(
# C:\Users\ams21\AppData\Local\Temp\ipykernel_6624\3340997814.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   ix = pd.read_csv(
# C:\Users\ams21\AppData\Local\Temp\ipykernel_6624\3340997814.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   ix = pd.read_csv(
# Error finding closest timestamp for SJU at 2023-08-31 00:10:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-31 19:33:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-31 15:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-31 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-30 02:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-30 19:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-30 15:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-30 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-29 00:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-29 19:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-29 15:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-29 12:55:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-19 12:53:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-19 13:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-18 03:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-18 18:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-18 15:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-18 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-17 00:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-17 19:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-17 15:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-17 14:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-16 23:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-16 19:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-16 15:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-06 23:33:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-06 15:42:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-06 01:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-06 19:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-06 15:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-06 13:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-06 12:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-05 00:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-05 15:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-05 01:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-05 19:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-05 15:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-05 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-05 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-04 23:59:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-04 15:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-04 01:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-04 19:08:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-04 15:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-04 13:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-03 23:33:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-03 15:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-28 23:43:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-28 19:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-28 15:11:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-28 12:54:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-27 00:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-27 15:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-27 19:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-27 15:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-27 13:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-27 13:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-26 23:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-26 15:45:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-26 20:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-26 16:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-26 13:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-26 13:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-16 12:55:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-15 23:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-15 19:58:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-15 15:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-15 14:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-14 02:35:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-14 19:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-14 15:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-14 13:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-13 23:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-13 15:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-13 01:44:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-13 19:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-13 15:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-13 13:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-03 19:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-03 15:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-03 13:56:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-02 00:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-02 15:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-02 19:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-02 15:08:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-02 13:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-01 00:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-01 15:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-01 19:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-01 15:10:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-01 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-25 23:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-25 19:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-25 15:10:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-25 13:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-24 00:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-24 19:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-24 15:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-24 13:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-23 00:55:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-23 19:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-23 15:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-23 13:14:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-22 23:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-13 13:56:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-12 01:32:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-12 15:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-12 01:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-12 19:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-12 15:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-12 12:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-12 13:14:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-11 23:52:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-11 15:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-11 01:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-11 19:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-11 15:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-11 13:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-10 23:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-10 15:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-10 19:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-10 15:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-10 13:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-22 19:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-22 15:35:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-22 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-21 23:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-21 18:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-21 15:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-21 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-20 23:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-20 15:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-20 18:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-20 15:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-08-20 12:52:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-20 13:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-19 00:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-19 15:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-19 19:08:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-19 15:10:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-09 23:53:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-09 15:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-09 19:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-09 15:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-09 13:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-08 23:54:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-08 15:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-08 19:43:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-08 15:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-08 12:55:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-07 23:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-08-07 15:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-08-07 19:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-08-07 15:32:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-08-07 13:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-27 15:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-27 13:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-26 15:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-26 13:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-25 15:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-25 13:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-18 13:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-17 15:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-17 13:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-16 15:02:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-16 13:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-15 15:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-15 13:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-04 23:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-09-04 19:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-04 15:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-04 14:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-03 23:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-09-03 15:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-09-03 19:11:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-03 15:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-09-03 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-03 13:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-02 23:53:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-09-02 15:43:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-09-02 19:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-02 15:10:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2023-09-02 12:56:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-02 13:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-30 03:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-09-30 15:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-30 15:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-30 13:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-29 23:44:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-29 15:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-29 13:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-28 15:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-28 12:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-14 15:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-14 13:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-13 16:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-13 13:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-12 15:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-12 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-01 00:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2023-09-01 19:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-01 15:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-01 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-24 15:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-24 12:45:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-23 15:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-23 13:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-22 15:02:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-22 13:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-21 15:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-11 15:08:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-11 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-10 15:02:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-10 13:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-09 15:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-09 13:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-08 15:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-21 13:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-20 15:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-20 13:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-19 14:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-19 13:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-18 15:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-08 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-07 15:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-07 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-06 15:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-06 13:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-09-05 15:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-09-05 13:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-31 15:32:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-31 14:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-30 16:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-30 13:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-10-29 15:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-29 15:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-29 20:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-29 13:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-28 00:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-10-28 15:58:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-19 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-18 00:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-18 15:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-18 12:56:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-17 23:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-17 14:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-17 13:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-16 23:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-16 14:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-16 13:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-06 14:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-06 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-05 23:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-05 16:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-05 14:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-04 23:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-04 15:11:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-04 13:58:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-03 00:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-03 15:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-25 15:08:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-25 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-24 23:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-24 15:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-24 13:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-23 23:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-23 15:02:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-23 13:54:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-22 23:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-22 15:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-15 23:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-15 15:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-15 19:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-14 23:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-10-14 15:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-14 15:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-14 13:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-13 00:36:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-13 15:14:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-13 13:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-03 13:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-02 23:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-02 14:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-02 13:36:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-01 23:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-01 15:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-01 13:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-28 15:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-28 13:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-27 23:52:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-27 15:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-27 13:59:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-26 23:48:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-26 15:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-26 13:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-25 00:33:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-12 23:38:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-12 15:32:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-12 13:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-11 00:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-11 15:11:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-11 13:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-10 23:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-10 15:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-10 13:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-09 23:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-22 13:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-21 23:32:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-10-21 15:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-21 14:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-21 13:44:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-20 23:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-20 15:14:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-20 13:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-19 23:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-19 15:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-09 15:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-09 13:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-08 23:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-08 14:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-08 13:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-07 23:19:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-10-07 15:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-07 15:43:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-10-07 13:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-10-06 23:54:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-30 16:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-30 14:40:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-29 16:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-29 14:42:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-28 16:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-28 14:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-16 16:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-16 14:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-15 16:38:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-15 14:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-14 16:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-14 14:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-13 16:27:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-02 15:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-02 13:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-01 15:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-01 13:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-27 16:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-27 14:36:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-11-26 16:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-26 16:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-26 21:09:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-26 14:50:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-11-25 16:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-25 16:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-25 21:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-25 14:18:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-24 17:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-24 14:16:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2023-11-13 14:42:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2023-11-12 16:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-12 16:35:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2023-11-12 21:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# ...
# Error finding closest timestamp for SJU at 2024-08-06 15:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-06 20:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-06 13:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-05 15:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-05 18:56:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-05 16:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-05 21:42:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-05 12:54:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-04 15:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-04 18:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-04 07:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-04 15:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-04 20:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2024-08-04 12:45:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-04 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-03 15:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-03 18:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-03 06:58:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-03 16:02:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-03 20:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-25 18:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-25 15:28:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-25 13:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-24 15:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-24 18:44:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-24 15:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-24 13:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-23 18:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-23 15:35:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-23 13:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-22 18:45:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-16 13:03:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-15 15:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-15 18:53:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-15 15:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-15 20:33:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-15 13:43:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-14 18:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-14 18:44:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-14 18:56:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-14 20:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-14 13:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-13 14:58:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-13 18:53:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-13 15:35:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-13 13:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2024-08-03 12:46:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-03 13:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-02 15:25:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-02 19:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-02 05:21:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-02 15:38:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-02 21:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-02 12:59:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-01 15:53:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-01 19:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-01 15:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-01 20:32:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-01 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-28 19:05:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-28 15:30:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-28 13:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-27 18:55:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-27 15:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-27 13:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-26 18:52:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-26 15:13:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-26 13:07:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-12 15:35:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-12 18:43:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-12 15:49:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-12 20:26:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-12 13:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-11 15:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-11 19:06:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-11 05:33:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-11 15:38:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-11 20:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2024-08-11 12:59:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-11 13:29:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-10 15:36:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-10 19:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-10 05:24:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-10 15:38:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-10 20:22:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for FCA at 2024-08-10 14:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-10 13:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-22 15:38:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-22 14:01:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-21 19:00:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-21 15:34:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-21 15:08:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-20 18:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-20 15:31:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-20 14:59:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-19 18:42:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-19 17:04:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-09 15:42:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-09 19:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-09 05:17:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-09 15:41:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-09 21:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-09 13:12:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-08 15:20:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-08 18:51:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-08 15:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-08 20:39:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-08 12:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-07 15:37:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for ANC at 2024-08-07 18:57:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-07 15:47:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for SJU at 2024-08-07 20:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for HNL at 2024-08-07 13:23:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
# Error finding closest timestamp for STT at 2024-08-06 15:15:00: unsupported operand type(s) for -: 'numpy.ndarray' and 'Timestamp'
#    ORIGIN_ceiling  ORIGIN_wind  ORIGIN_visibility  ORIGIN_precip  \
# 0         25000.0          0.0               10.0            NaN
# 1         25000.0          0.0               10.0            NaN
# 2         25000.0          2.0               10.0            NaN
# 3         25000.0          8.0               10.0            0.0
# 4         25000.0          5.0               10.0            NaN
#
#    DEST_ceiling  DEST_wind  DEST_visibility  DEST_precip
# 0       25000.0       10.0             10.0          NaN
# 1       25000.0        NaN             10.0          NaN
# 2       25000.0       11.0             10.0          NaN
# 3       25000.0        2.0             10.0          NaN
# 4       25000.0        7.0             10.0          NaN
# ORIGIN_ceiling       25000.0
# ORIGIN_wind              0.0
# ORIGIN_visibility       10.0
# ORIGIN_precip            NaN
# DEST_ceiling         25000.0
# DEST_wind               10.0
# DEST_visibility         10.0
# DEST_precip              NaN
# Name: 0, dtype: float64
# Data saved to 'flights-wx.csv'
